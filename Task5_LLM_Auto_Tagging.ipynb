# %% [markdown]
# # Task 5: Auto Tagging Support Tickets Using LLM
#
# ## Problem Statement & Objective
#
# **Problem:** Customer support teams receive thousands of tickets daily. Manually categorizing each ticket into tags is time-consuming and inconsistent.
#
# **Objective:** Use a Large Language Model (LLM) to automatically tag support tickets into categories:
# - Technical Issue
# - Billing Question
# - Account Management
# - Product Inquiry
# - Complaint
# - Other
#
# **Approaches:**
# 1. Zero-shot learning (no examples)
# 2. Few-shot learning (with examples)
#
# **Dataset:** Sample support ticket dataset
#
# **Skills Gained:**
# - Prompt engineering
# - LLM-based text classification
# - Zero-shot and few-shot learning

# %%
# Cell 2: Import libraries only (no installation)
from transformers import pipeline
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

print("✅ Libraries imported successfully")

# Test if model can load
print("Testing model loader...")
classifier = pipeline("zero-shot-classification", model="typeform/distilbert-base-uncased-mnli")
print("✅ Model ready")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Cell 2: Import libraries only (no installation)
# ----> 2 from transformers import pipeline
#       3 import pandas as pd
#       4 import warnings
#       5 warnings.filterwarnings('ignore')
#
# File <frozen importlib._bootstrap>:1231, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File E:\python.projects\ai-assistant\venv\Lib\site-packages\transformers\utils\import_utils.py:2212, in _LazyModule.__getattr__(self, name)
#    2210 elif name in self._class_to_module:
#    2211     try:
# -> 2212         module = self._get_module(self._class_to_module[name])
#    2213         value = getattr(module, name)
#    2214     except (ModuleNotFoundError, RuntimeError, AttributeError) as e:
#    2215         # V5: If trying to import a *TokenizerFast symbol, transparently fall back to the
# ...

# %%
python -c "from transformers import pipeline; print('transformers OK')"
# Out:
#   Cell In[3], line 1
#     python -c "from transformers import pipeline; print('transformers OK')"
#               ^
# SyntaxError: invalid syntax

# %%
from transformers import pipeline
print("transformers OK")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from transformers import pipeline
#       2 print("transformers OK")
#
# File <frozen importlib._bootstrap>:1231, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File E:\python.projects\ai-assistant\venv\Lib\site-packages\transformers\utils\import_utils.py:2212, in _LazyModule.__getattr__(self, name)
#    2210 elif name in self._class_to_module:
#    2211     try:
# -> 2212         module = self._get_module(self._class_to_module[name])
#    2213         value = getattr(module, name)
#    2214     except (ModuleNotFoundError, RuntimeError, AttributeError) as e:
#    2215         # V5: If trying to import a *TokenizerFast symbol, transparently fall back to the
#    2216         # non-Fast symbol from the same module when available. This lets us keep only one
# ...
